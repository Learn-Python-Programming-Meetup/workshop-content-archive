# %% [markdown]
# ##### Data Source:https://www.kaggle.com/husainsb/lendingclub-issued-loans?select=lc_2016_2017.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('lc_2016_2017.csv', low_memory=False)

# %%
df.head()

# %%
df.shape

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 759338 entries, 0 to 759337
# Data columns (total 72 columns):
# id                             759338 non-null int64
# member_id                      0 non-null float64
# loan_amnt                      759338 non-null int64
# funded_amnt                    759338 non-null int64
# funded_amnt_inv                759338 non-null float64
# term                           759338 non-null object
# int_rate                       759338 non-null float64
# installment                    759338 non-null float64
# grade                          759338 non-null object
# sub_grade                      759338 non-null object
# emp_title                      708368 non-null object
# emp_length                     708975 non-null object
# home_ownership                 759338 non-null object
# annual_inc                     759338 non-null float64
# verification_status            759338 non-null object
# issue_d                        759338 non-null object
# loan_status                    759338 non-null object
# pymnt_plan                     759338 non-null object
# desc                           17 non-null object
# purpose                        759338 non-null object
# title                          736165 non-null object
# zip_code                       759337 non-null object
# addr_state                     759338 non-null object
# dti                            758983 non-null float64
# delinq_2yrs                    759338 non-null int64
# earliest_cr_line               759338 non-null object
# inq_last_6mths                 759337 non-null float64
# mths_since_last_delinq         396633 non-null float64
# mths_since_last_record         141179 non-null float64
# open_acc                       759338 non-null int64
# pub_rec                        759338 non-null int64
# revol_bal                      759338 non-null float64
# revol_util                     758821 non-null float64
# total_acc                      759338 non-null int64
# initial_list_status            759338 non-null object
# out_prncp                      759338 non-null float64
# out_prncp_inv                  759338 non-null float64
# total_pymnt                    759338 non-null float64
# total_pymnt_inv                759338 non-null float64
# total_rec_prncp                759338 non-null float64
# total_rec_int                  759338 non-null float64
# total_rec_late_fee             759338 non-null float64
# recoveries                     759338 non-null float64
# collection_recovery_fee        759338 non-null float64
# last_pymnt_d                   758390 non-null object
# last_pymnt_amnt                759338 non-null float64
# next_pymnt_d                   591423 non-null object
# last_credit_pull_d             759320 non-null object
# collections_12_mths_ex_med     759338 non-null int64
# mths_since_last_major_derog    215105 non-null float64
# policy_code                    759338 non-null int64
# application_type               759338 non-null object
# annual_inc_joint               34003 non-null float64
# dti_joint                      34001 non-null float64
# verification_status_joint      34003 non-null object
# acc_now_delinq                 759338 non-null int64
# tot_coll_amt                   759338 non-null float64
# tot_cur_bal                    759338 non-null float64
# open_acc_6m                    759276 non-null float64
# open_il_12m                    759277 non-null float64
# open_il_24m                    759277 non-null float64
# mths_since_rcnt_il             738795 non-null float64
# total_bal_il                   759277 non-null float64
# il_util                        658743 non-null float64
# open_rv_12m                    759277 non-null float64
# open_rv_24m                    759277 non-null float64
# max_bal_bc                     759277 non-null float64
# all_util                       759224 non-null float64
# total_rev_hi_lim               759338 non-null float64
# inq_fi                         759277 non-null float64
# total_cu_tl                    759276 non-null float64
# inq_last_12m                   759276 non-null float64
# dtypes: float64(40), int64(10), object(22)
# memory usage: 417.1+ MB

# %%
df.describe()
# Out:
#                  id  member_id      loan_amnt    funded_amnt  funded_amnt_inv  \
# count  7.593380e+05        0.0  759338.000000  759338.000000    759338.000000
# mean   9.317508e+07        NaN   14707.775260   14707.738385     14702.529098
# std    1.536975e+07        NaN    9215.456493    9215.456467      9213.003636
# min    5.571600e+04        NaN    1000.000000    1000.000000       775.000000
# 25%    7.880009e+07        NaN    7500.000000    7500.000000      7500.000000
# 50%    9.279886e+07        NaN   12000.000000   12000.000000     12000.000000
# 75%    1.072904e+08        NaN   20000.000000   20000.000000     20000.000000
# max    1.201229e+08        NaN   40000.000000   40000.000000     40000.000000
#
#             int_rate    installment    annual_inc            dti  \
# count  759338.000000  759338.000000  7.593380e+05  758983.000000
# mean       13.187041     442.584639  7.996778e+04      18.980803
# std         5.054311     275.739578  1.634141e+05      13.363398
# min         5.320000      30.120000  0.000000e+00      -1.000000
# 25%         9.750000     241.700000  4.800000e+04      12.260000
# 50%        12.620000     370.840000  6.700000e+04      18.180000
# 75%        15.590000     590.505000  9.500000e+04      24.780000
# max        30.990000    1719.830000  1.100000e+08     999.000000
#
#          delinq_2yrs  ...  total_bal_il        il_util    open_rv_12m  \
# count  759338.000000  ...  7.592770e+05  658743.000000  759277.000000
# mean        0.357795  ...  3.572216e+04      70.017316       1.339577
# std         0.951763  ...  4.324080e+04      23.661354       1.521418
# min         0.000000  ...  0.000000e+00       0.000000       0.000000
# 25%         0.000000  ...  9.312000e+03      56.000000       0.000000
# 50%         0.000000  ...  2.361100e+04      73.000000       1.000000
# 75%         0.000000  ...  4.634200e+04      86.000000       2.000000
# max        42.000000  ...  1.711009e+06    1000.000000      28.000000
#
#          open_rv_24m     max_bal_bc       all_util  total_rev_hi_lim  \
# count  759277.000000  759277.000000  759224.000000      7.593380e+05
# mean        2.848091    5790.295344      59.259296      3.448430e+04
# std         2.622519    5580.465864      20.473969      3.515591e+04
# min         0.000000       0.000000       0.000000      0.000000e+00
# 25%         1.000000    2369.000000      46.000000      1.460000e+04
# 50%         2.000000    4417.000000      60.000000      2.530000e+04
# 75%         4.000000    7500.000000      74.000000      4.290000e+04
# max        60.000000  776843.000000     211.000000      2.175000e+06
#
#               inq_fi    total_cu_tl   inq_last_12m
# count  759277.000000  759276.000000  759276.000000
# mean        0.968562       1.475229       2.107460
# std         1.484057       2.681394       2.402594
# min         0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       1.000000
# 75%         1.000000       2.000000       3.000000
# max        48.000000     111.000000      49.000000
#
# [8 rows x 50 columns]

# %% [markdown]
# ### Remove Null

# %%
df.isnull().sum()
# Out:
# id                                  0
# member_id                      759338
# loan_amnt                           0
# funded_amnt                         0
# funded_amnt_inv                     0
# term                                0
# int_rate                            0
# installment                         0
# grade                               0
# sub_grade                           0
# emp_title                       50970
# emp_length                      50363
# home_ownership                      0
# annual_inc                          0
# verification_status                 0
# issue_d                             0
# loan_status                         0
# pymnt_plan                          0
# desc                           759321
# purpose                             0
# title                           23173
# zip_code                            1
# addr_state                          0
# dti                               355
# delinq_2yrs                         0
# earliest_cr_line                    0
# inq_last_6mths                      1
# mths_since_last_delinq         362705
# mths_since_last_record         618159
# open_acc                            0
#                                 ...
# recoveries                          0
# collection_recovery_fee             0
# last_pymnt_d                      948
# last_pymnt_amnt                     0
# next_pymnt_d                   167915
# last_credit_pull_d                 18
# collections_12_mths_ex_med          0
# mths_since_last_major_derog    544233
# policy_code                         0
# application_type                    0
# annual_inc_joint               725335
# dti_joint                      725337
# verification_status_joint      725335
# acc_now_delinq                      0
# tot_coll_amt                        0
# tot_cur_bal                         0
# open_acc_6m                        62
# open_il_12m                        61
# open_il_24m                        61
# mths_since_rcnt_il              20543
# total_bal_il                       61
# il_util                        100595
# open_rv_12m                        61
# open_rv_24m                        61
# max_bal_bc                         61
# all_util                          114
# total_rev_hi_lim                    0
# inq_fi                             61
# total_cu_tl                        62
# inq_last_12m                       62
# Length: 72, dtype: int64

# %%
df.isna().any()
# Out:
# id                             False
# member_id                       True
# loan_amnt                      False
# funded_amnt                    False
# funded_amnt_inv                False
# term                           False
# int_rate                       False
# installment                    False
# grade                          False
# sub_grade                      False
# emp_title                       True
# emp_length                      True
# home_ownership                 False
# annual_inc                     False
# verification_status            False
# issue_d                        False
# loan_status                    False
# pymnt_plan                     False
# desc                            True
# purpose                        False
# title                           True
# zip_code                        True
# addr_state                     False
# dti                             True
# delinq_2yrs                    False
# earliest_cr_line               False
# inq_last_6mths                  True
# mths_since_last_delinq          True
# mths_since_last_record          True
# open_acc                       False
#                                ...
# recoveries                     False
# collection_recovery_fee        False
# last_pymnt_d                    True
# last_pymnt_amnt                False
# next_pymnt_d                    True
# last_credit_pull_d              True
# collections_12_mths_ex_med     False
# mths_since_last_major_derog     True
# policy_code                    False
# application_type               False
# annual_inc_joint                True
# dti_joint                       True
# verification_status_joint       True
# acc_now_delinq                 False
# tot_coll_amt                   False
# tot_cur_bal                    False
# open_acc_6m                     True
# open_il_12m                     True
# open_il_24m                     True
# mths_since_rcnt_il              True
# total_bal_il                    True
# il_util                         True
# open_rv_12m                     True
# open_rv_24m                     True
# max_bal_bc                      True
# all_util                        True
# total_rev_hi_lim               False
# inq_fi                          True
# total_cu_tl                     True
# inq_last_12m                    True
# Length: 72, dtype: bool

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['member_id',
#  'emp_title',
#  'emp_length',
#  'desc',
#  'title',
#  'zip_code',
#  'dti',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'revol_util',
#  'last_pymnt_d',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'mths_since_last_major_derog',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'open_acc_6m',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m']

# %%
df.loc[:, df.isna().any()].isnull().sum()
# Out:
# emp_title             50970
# emp_length            50363
# title                 23173
# zip_code                  1
# dti                     355
# inq_last_6mths            1
# revol_util              517
# last_pymnt_d            948
# last_credit_pull_d       18
# open_acc_6m              62
# open_il_12m              61
# open_il_24m              61
# mths_since_rcnt_il    20543
# total_bal_il             61
# open_rv_12m              61
# open_rv_24m              61
# max_bal_bc               61
# all_util                114
# inq_fi                   61
# total_cu_tl              62
# inq_last_12m             62
# dtype: int64

# %%
df.drop([
    'member_id', 
    'desc',
    'next_pymnt_d',
    'mths_since_last_major_derog',
    'annual_inc_joint', 
    'dti_joint', 
    'verification_status_joint', 
    'il_util', 
    'mths_since_last_delinq', 
    'mths_since_last_record'],axis=1,inplace=True,errors='ignore')

# %% [markdown]
# ### Understand Data

# %%
df.loan_status.unique()
# Out:
# array(['Current', 'Fully Paid', 'In Grace Period', 'Late (31-120 days)',
#        'Late (16-30 days)', 'Charged Off', 'Default'], dtype=object)

# %%
df.loan_status.value_counts()
# Out:
# Current               565523
# Fully Paid            130718
# Charged Off            37197
# Late (31-120 days)     15354
# In Grace Period         6634
# Late (16-30 days)       3876
# Default                   36
# Name: loan_status, dtype: int64

# %%
f,ax = plt.subplots(figsize=(15,6))
ax = sns.countplot(df.loan_status, palette="muted")
ax.set_title('Loan Status in DataSet')
plt.show()

# %%
df.purpose.value_counts()
# Out:
# debt_consolidation    431530
# credit_card           157768
# home_improvement       57197
# other                  50680
# major_purchase         18319
# medical                10360
# car                     8777
# small_business          8235
# vacation                6416
# moving                  5973
# house                   3561
# renewable_energy         519
# wedding                    3
# Name: purpose, dtype: int64

# %%
f,ax = plt.subplots(figsize=(15,6))
ax = sns.countplot(df.purpose, palette="muted")
ax.set_title('Loan Purpose in DataSet')
plt.show()

# %%
f,ax = plt.subplots(figsize=(15,6))
g = sns.distplot(df["loan_amnt"])
g.set_xlabel("Loan Amount Value", fontsize=16)
g.set_ylabel("Frequency", fontsize=16)
g.set_title("Loan Amount Distribuition", fontsize=20)
# Out:
# Text(0.5,1,'Loan Amount Distribuition')

# %%
df['int_round'] = df['int_rate'].round().astype(int)

f,ax = plt.subplots(figsize=(15,6))
g1 = sns.countplot(x="int_round", data=df, 
                  color='blue')
g1.set_xlabel("Loan Interest Rate", fontsize=16)
g1.set_ylabel("Count", fontsize=16)
g1.set_title("Interest Rate Distribuition", fontsize=20)
# Out:
# Text(0.5,1,'Interest Rate Distribuition')

# %%
f,ax = plt.subplots(figsize=(15,6))
g1 = sns.boxplot(x="loan_status", y="int_round", data=df, 
                 color='blue')
g1.set_xticklabels(g1.get_xticklabels(),rotation=45)
g1.set_xlabel("Loan Status Categories", fontsize=12)
g1.set_ylabel("Interest Rate Distribution", fontsize=15)
g1.set_title("Loan Status by Interest Rate", fontsize=20)
# Out:
# Text(0.5,1,'Loan Status by Interest Rate')

# %%
f,ax = plt.subplots(figsize=(15,6))
g2 = sns.boxplot(x="loan_status", y="loan_amnt", data=df, 
                 color='blue')
g2.set_xticklabels(g2.get_xticklabels(),rotation=45)
g2.set_xlabel("Loan Status Categories", fontsize=15)
g2.set_ylabel("Loan Amount Distribution", fontsize=15)
g2.set_title("Loan Status by Loan Amount", fontsize=20)
# Out:
# Text(0.5,1,'Loan Status by Loan Amount')

# %%
df['issue_d']
# Out:
# 0         Jun-2017
# 1         Jun-2017
# 2         Jun-2017
# 3         Jun-2017
# 4         Jun-2017
# 5         Jun-2017
# 6         Jun-2017
# 7         Jun-2017
# 8         Jun-2017
# 9         Jun-2017
# 10        Jun-2017
# 11        Jun-2017
# 12        Jun-2017
# 13        Jun-2017
# 14        Jun-2017
# 15        Jun-2017
# 16        Jun-2017
# 17        Jun-2017
# 18        Jun-2017
# 19        Jun-2017
# 20        Jun-2017
# 21        Jun-2017
# 22        Jun-2017
# 23        Jun-2017
# 24        Jun-2017
# 25        Jun-2017
# 26        Jun-2017
# 27        Jun-2017
# 28        Jun-2017
# 29        Jun-2017
#             ...
# 759308    Jan-2016
# 759309    Jan-2016
# 759310    Jan-2016
# 759311    Jan-2016
# 759312    Jan-2016
# 759313    Jan-2016
# 759314    Jan-2016
# 759315    Jan-2016
# 759316    Jan-2016
# 759317    Jan-2016
# 759318    Jan-2016
# 759319    Jan-2016
# 759320    Jan-2016
# 759321    Jan-2016
# 759322    Jan-2016
# 759323    Jan-2016
# 759324    Jan-2016
# 759325    Jan-2016
# 759326    Jan-2016
# 759327    Jan-2016
# 759328    Jan-2016
# 759329    Jan-2016
# 759330    Jan-2016
# 759331    Jan-2016
# 759332    Jan-2016
# 759333    Jan-2016
# 759334    Jan-2016
# 759335    Jan-2016
# 759336    Jan-2016
# 759337    Jan-2016
# Name: issue_d, Length: 759338, dtype: object

# %%
df['issue_month'], df['issue_year'] = df['issue_d'].str.split('-', 1).str

# %%
#Exploring the loan_status x purpose
purp_loan= ['purpose', 'loan_status']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df[purp_loan[0]], df[purp_loan[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row0_col0 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row0_col1 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row0_col3 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row0_col4 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row0_col5 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row0_col6 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row1_col0 {
#             background-color:  #a3daa3;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row1_col1 {
#             background-color:  #8ecf8e;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row1_col2 {
#             background-color:  #8ecf8e;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row1_col3 {
#             background-color:  #97d497;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row1_col4 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row1_col5 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row1_col6 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row2_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row2_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row2_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row2_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row2_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row2_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row2_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row3_col0 {
#             background-color:  #cdf2cd;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row3_col1 {
#             background-color:  #c8efc8;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row3_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row3_col3 {
#             background-color:  #c5edc5;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row3_col4 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row3_col5 {
#             background-color:  #c7eec7;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row3_col6 {
#             background-color:  #cdf2cd;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row4_col0 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row4_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row4_col2 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row4_col3 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row4_col4 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row4_col5 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row4_col6 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row5_col0 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row5_col1 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row5_col2 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row5_col3 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row5_col4 {
#             background-color:  #ddfbdd;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row5_col5 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row5_col6 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row6_col0 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row6_col1 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row6_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row6_col3 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row6_col4 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row6_col5 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row6_col6 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row7_col0 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row7_col1 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row7_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row7_col3 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row7_col4 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row7_col5 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row7_col6 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row8_col0 {
#             background-color:  #cbf1cb;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row8_col1 {
#             background-color:  #cbf1cb;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row8_col2 {
#             background-color:  #b0e1b0;
#             color:  #000000;
#         }    #T_05b93607_3360_11eb_96c7_3af9d3a2e6c4row8_col3 {
#             background-color:  #caf0ca;
#             color:  #000000;

# %%
plt.figure(figsize=(12,5))

# df_installment=df[df.installment < 750]['installment']
df_installment = df['installment']

sns.distplot(df_installment)
plt.title("Installment Distribution", fontsize=20)
plt.xlabel("Installment Range", fontsize=17)
plt.ylabel("Density", fontsize=17)
plt.show()

# %% [markdown]
# ## References:
# + https://www.kaggle.com/kabure/lending-club-insightful-financial-eda
